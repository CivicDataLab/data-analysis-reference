# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
risk_score = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\risk_score_final_district.csv')
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_392\2599403425.py:1: DtypeWarning: Columns (28,29,30,31,32,68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   risk_score = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\risk_score_final_district.csv')

# %%
monsoon = ['2024_06','2024_07','2024_08','2024_09']

# %%
bar_monsoon = risk_score.loc[(risk_score['district'] == 'SIVSAGAR') & (risk_score['timeperiod'].isin(monsoon))]

# %%
bar_monsoon.sort_values(['topsis-score','object-id',],ascending=False)
# Out:
#       object-id  district  rc-area timeperiod  total-tender-awarded-value  \
# 7022        165  SIVSAGAR    478.0    2024_07                        0.00
# 7023        166  SIVSAGAR    388.0    2024_07                 85326651.48
# 7204        165  SIVSAGAR    478.0    2024_08                        0.00
# 7206        166  SIVSAGAR    388.0    2024_08                 13499698.00
# 7401        165  SIVSAGAR    478.0    2024_09                        0.00
# 7088        168  SIVSAGAR    386.0    2024_07                        0.00
# 7247        168  SIVSAGAR    386.0    2024_08                        0.00
# 7423        166  SIVSAGAR    388.0    2024_09                        0.00
# 7256        167  SIVSAGAR    315.0    2024_08                        0.00
# 6964        165  SIVSAGAR    478.0    2024_06                        0.00
# 6996        166  SIVSAGAR    388.0    2024_06                        0.00
# 6998        168  SIVSAGAR    386.0    2024_06                        0.00
# ...

# %%
from datetime import date, timedelta, datetime

#snapshot_ld_dist['datetime'] = pd.to_datetime(snapshot_ld_dist['timeperiod'], format='%Y_%m')
bar_monsoon['timeperiod_iso'] = bar_monsoon['timeperiod'].str.replace('_', '-') #+ '-01'

# Step 2: Convert the modified column to datetime format
#snapshot_ld_dist['timeperiod_iso'] = pd.to_datetime(snapshot_ld_dist['timeperiod_iso'], format='%Y-%m-%d')
bar_monsoon['timeperiod_iso'] = pd.to_datetime(bar_monsoon['timeperiod_iso'], format='%Y-%m')


bar_monsoon['timeperiod_iso'] = bar_monsoon['timeperiod_iso'].dt.strftime('%Y-%m')
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_392\2064550297.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bar_monsoon['timeperiod_iso'] = bar_monsoon['timeperiod'].str.replace('_', '-') #+ '-01'
# C:\Users\saura\AppData\Local\Temp\ipykernel_392\2064550297.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bar_monsoon['timeperiod_iso'] = pd.to_datetime(bar_monsoon['timeperiod_iso'], format='%Y-%m')
# ...

# %%
bar_monsoon.to_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Dashboards\Flood_report\barpeta_monsoon_2024.csv')
