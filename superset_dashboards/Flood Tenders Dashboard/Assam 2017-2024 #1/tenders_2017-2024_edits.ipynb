# %%
import pandas as pd
import numpy as np

# %%
og = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Dashboards\Flood Tenders Dashboard\sqllab_query_assam_flood_tenders_20240930T091542.csv')
og
# Out:
#       s_no          tender_id      tender_externalreference  \
# 0       11   2018_DoWR_6310_2       HAILAKANDI/RIDF-XXIII/1
# 1      127  2019_DoWR_11627_1    HAILAKANDI/2018-19/SDRF/IV
# 2      141  2019_DoWR_11622_1     HAILAKANDI/2018-19/SDRF/V
# 3      151  2019_DoWR_11496_1    HAILAKANDI/2018-19/SDRF/II
# 4      268  2019_DoWR_11623_1    HAILAKANDI/2018-19/SDRF/VI
# ...    ...                ...                           ...
# 2363  2294   2021_PWD_22958_1        EE/JDTTRD/SDRF/NIT/328
# 2364  2303  2020_DoWR_16825_2   TEZPUR/2019-20/SOPD-FDR/III
# 2365  2318  2020_DoWR_16600_1  NALBARI/2019-20/SOPD-FDR/III
# 2366  2330  2020_DoWR_17137_1   JOR/SDRF/GELABEEL/2019-20/1
# 2367  2350  2020_DoWR_16357_1  SILCHAR/2019-20/SOPD-FDR/III
#
#                                            tender_title  \
# 0          A E Measures to Protect Sahabad-Rongpur area
# 1                        IM FROM MOHANPUR TO CONFLUENCE
# 2                          IM to protect Nandigram Area
# ...

# %%
update = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Dashboards\Flood Tenders Dashboard\floodtenders_RCgeotagged.csv')
update.columns = update.columns.str.lower().str.replace(' ', '_')
update = update.rename(columns={'contract_date_:':'contract_date','bid_validity(days)':'bid_validity_days','tender_value_in_₹':'tender_value_in_rupees'})
update['tender_value_in_rupees'] = update['tender_value_in_rupees'].str.replace(',', '')
update['tender_value_in_rupees'] = update['tender_value_in_rupees'].astype(float)
update = update.dropna(subset=['awarded_value', 'tender_value_in_rupees','district_finalised'])
update['awarded_value'] = update['awarded_value'].str.replace(',', '')
update['awarded_value'] = update['awarded_value'].astype(float)
update
# Out:
#       unnamed:_0          tender_id    tender_externalreference  \
# 0            159   2017_DoWR_2083_1   Hailakandi/SDRF/2016-17/2
# 1            160   2017_DoWR_2238_1   Hailakandi/SDRF/2016-17/2
# 2            210   2018_DoWR_5796_1   HAILAKANDI/SDRF/2017-18/1
# 3            372   2018_DoWR_6310_2     HAILAKANDI/RIDF-XXIII/1
# 4            552  2019_DoWR_11496_1  HAILAKANDI/2018-19/SDRF/II
# ...          ...                ...                         ...
# 2691        2637  2024_DoWR_36038_1       MAJULI/2023-24/NIDA/I
# 2692        2645  2024_DoWR_36137_1     CACHAR/2023-24/NIDA/III
# 2693        2673   2023_SCD_34601_8  Tender/NIT/Pt/2023-24/7736
# 2694        2680  2024_DoWR_36023_2     GOLAGHAT/2023-24/NIDA/I
# 2695        2682  2024_DoWR_36478_1     DHEMAJI/2023-24/NIDA/II
#
#                                            tender_title  \
# 0                                 Dhaleswari Katakhal 1
# 1              Dhaleswari Katakhal Drainage Basin Ph-II
# ...

# %%
update.to_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Dashboards\Flood Tenders Dashboard\floodtenders_2017-24.csv')
